# %% [markdown]
# This script replaces hydrogen names in XOP after babel has added its hydrogens at the end of the pdb file\n
# I assume that the tropinol is protonated and its name remains "H"\n
# all other hydrogens are remaned in sequential order\n
#
# this script is extremely ad hoc so hydrogens order may not be correct for other docking runs\n
# check manually for consistency every time
#
# sometimes you can just use a straight 0 - 23 renaming of babel hydrogens (check the R and S lists)

# %%
import os

# %%
order = ["P",
            "O"   ,
            "O1"  ,
            "O2" ,
            "O3"  ,
            "O4"  ,
            "N"   ,
            "H"   ,
            "N1"  ,
            "C"   ,
            "H1"  ,
            "C1"  ,
            "H2"  ,
            "C2"  ,
            "H3"  ,
            "H4"  ,
            "C3"  ,
            "H5"  ,
            "H6"  ,
            "C4"  ,
            "H7"  ,
            "H8"  ,
            "C5"  ,
            "H9"  ,
            "H10" ,
            "C6"  ,
            "H11" ,
            "C7"  ,
            "H12" ,
            "H13" ,
            "H14" ,
            "C8"  ,
            "C9"  ,
            "H15" ,
            "C10" ,
            "H16" ,
            "C11" ,
            "C12" ,
            "H17" ,
            "C13" ,
            "H18" ,
            "C14", 
            "H19",
            "C15",
             "H20",
             "C16",
             "H21",
             "C17",
             "H22",
             "C18",
             "H23",
             "C19"]
# for hydrogens babel(to be changed) - ff(real value)
S = ["H",
     "H16",
     "H18",
     "H19",
     "H17",
     "H15",
     "H11",
     "H9",
     "H10",
     "H2", 
     "H3",
     "H4",
     "H5",
     "H6",
     "H1", 
     "H8", 
     "H7",
     "H12",
     "H13",
     "H14",
     "H20",
     "H22",
     "H23",
     "H21"]
   

R = ["H",
     "H16",
     "H18",
     "H19",
     "H17",
     "H15",
     "H20",
     "H22",
     "H23",
     "H21",
     "H11",
     "H9",
     "H10",
     "H2",
     "H3",
     "H4",
     "H5",
     "H6",
     "H1",
     "H7",
     "H8",
     "H12",
     "H13",
     "H14"]

R = ["H", 
"H1", 
"H2", 
"H3", 
"H4", 
"H5", 
"H6", 
"H7", 
"H8", 
"H9", 
"H10", 
"H11", 
"H12", 
"H13", 
"H14", 
"H15", 
"H16", 
"H17", 
"H18", 
"H19", 
"H20", 
"H21", 
"H22", 
"H23"]


### these are most likely obsolete
atom_list_old=[ "P","O2", "O", "C6", "C5", "C", "N", "C3","C1", "C7", "H", "C2", "C4", "O1",\
           "C11", "C15", "C17", "C19", "N1", "C18", "O3", "O4", "C16", "C8", "C9",
           "C12", "C14", "C13", "C10",
           "H11" ,"H8","H7","H2","H4","H3","H1","H12","H13","H14","H6","H5",
           "H10","H9","H20","H22","H23","H21","H15","H17","H19","H18","H16"]

atom_list_R=[ "P","O2", "O", "C6", "C5", "C", "N", "C3","C1", "C7", "H", "C2", "C4", "O1",\
           "C11", "C15", "C17", "C19", "N1", "C18", "O3", "O4", "C16", "C8", "C9",
           "C12", "C14", "C13", "C10",
           "H11" ,"H8","H7","H2","H4","H3","H1","H12","H13","H14","H6","H5",
           "H10","H9","H20","H22","H23","H21","H15","H17","H19","H18","H16"]

atom_listS=[ "P","O2", "O", "C6", "C5", "C", "N", "C3","C1", "C7", "H", "C2", "C4", "O1",\
           "C11", "C15", "C17", "C19", "N1", "C18", "O3", "O4", "C16", "C8", "C9",
           "C12", "C14", "C13", "C10",
           "H11" ,"H8","H7","H2","H4","H3","H1","H12","H13","H14","H6","H5",
           "H10","H9","H20","H22","H23","H21","H15","H17","H19","H18","H16"]

# %%
dirs = []
for d in os.walk("."):
    dirs.append(d[0])
dirs = dirs[1:-3]

# %%
dirs = ['a1',
 'a21',
 'a43',
 'a46',
 'a49',
 'a5',
 'a7',]

# %% [markdown]
# # S

# %%
best =[['/home/domain/data/kirill/AB/XOP/docking/lom_results/a21wt_fixed/S23.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf0_3rel_32_82_em_nvt7_fixed/S52.pdbqt',  '8'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf0_3rel_8_22_em_nvt33_fixed/S59.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_55_em_nvt22_fixed/S14.pdbqt',  '2'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_78_em_nvt24_fixed/S64.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_8_34_em_nvt13_fixed/S21.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_61_55_em_nvt8_fixed/S44.pdbqt',  '8'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_68_41_em_nvt10_fixed/S37.pdbqt',  '3'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf1_2rel_42_97_em_nvt29_fixed/S48.pdbqt',  '8'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9_newrel_4_33_em_nvt9_fixed/S94.pdbqt',  '1'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9_newrel_60_11_em_nvt2_fixed/S99.pdbqt',  '7'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_1_12_em_nvt15_fixed/S47.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_17_86_em_nvt2_fixed/S3.pdbqt',  '8'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_2_73_em_nvt10_fixed/S41.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_33_5_em_nvt39_fixed/S91.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_34_41_em_nvt40_fixed/S47.pdbqt',  '9'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_39_55_em_nvt23_fixed/S85.pdbqt',  '5'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_7_30_em_nvt30_fixed/S11.pdbqt',  '5'],
 ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5wt/S73.pdbqt', '8']]

# %%
for f in best:
    # !babel -ipdbqt {f[0]} -h -opdb {f[0][:-6]+"h.pdb"} 
    with open(f[0][:-6]+"h.pdb") as fl:
        lines = fl.readlines()
    print f[0]
    strings = []
    for line in lines:
        if "MODEL" in line:
            model = line.split()[-1]
            if model == f[1]:
                strings.append(line)
            atoms = []

        if line[0:6].split()[0] == 'ATOM' and model == f[1]: 
            # create a dict for every line stating with ATOM
            atoms.append({\
                'AtomSerial':line[6:11].replace(' ',''),\
                'AtomName':line[12:16].replace(' ',''),\
                'AltLoc':line[16].replace(' ',''),\
                'ResName':line[17:20].replace(' ',''),\
                'Chain':line[21].replace(' ',''),\
                'ResNum':int(line[22:26].replace(' ','')),\
                'ResIns':line[26].replace(' ',''),\
                'x':float(line[30:38].replace(' ','')),\
                'y':float(line[38:46].replace(' ','')),\
                'z':float(line[46:54].replace(' ','')),\
                'Occupancy':line[54:60].replace(' ',''),\
                'TempFactor':line[60:66].replace(' ',''),\
                'SegmentID':line[72:76].replace(' ',''),\
                'ElementSymb':line[76:78].replace(' ',''),\
                'Charge':line[78:81].replace(' ','')})


        if "ENDMDL" in line and model == f[1]:           
            # Iterate over atoms and replace their names
            hyds = list(S)
            for at in range(len(atoms)):
                if "H" in atoms[at]["AtomName"]: 
                    atoms[at]["AtomName"] = hyds.pop(0)  

            # reorder atoms in "atoms" so they match .itp         
            reorder = [order.index(atom["AtomName"]) for atom in atoms]
            atoms = [atoms[i] for i in reorder]
            print len(atoms)
            # prepare for output
            num = 0
            for atom in atoms:
                num +=1
                strings.append("%-6s%5d  %-4s%-3s %1s%4d    %8.3f%8.3f%8.3f%6.2s%6.2s          %2s%2s\n"%\
                                ("ATOM", num, atom['AtomName'], atom['ResName'],\
                                 atom['Chain'], atom["ResNum"], atom['x'], atom['y'], atom['z'],'', '', "",""))
            strings.append("ENDMDL\n")
            break
    with open(f[0][:-6] + "-ready.pdb",'w') as ff:
        ff.writelines(strings)
# Out:
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a21wt_fixed/S23.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf0_3rel_32_82_em_nvt7_fixed/S52.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf0_3rel_8_22_em_nvt33_fixed/S59.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_55_em_nvt22_fixed/S14.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_78_em_nvt24_fixed/S64.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_8_34_em_nvt13_fixed/S21.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# ...

# %%
bestR = [
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf0_3rel_32_82_em_nvt7_fixed/R42.pdbqt',  '6'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_55_em_nvt22_fixed/R65.pdbqt',  '9'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_78_em_nvt24_fixed/R4.pdbqt',  '7'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_8_34_em_nvt13_fixed/R21.pdbqt',  '9'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_57_60_em_nvt_fixed/R13.pdbqt',  '4'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_61_55_em_nvt8_fixed/R29.pdbqt',  '5'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_68_41_em_nvt10_fixed/R63.pdbqt',  '9'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9_newrel_4_33_em_nvt9_fixed/R92.pdbqt',  '9'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9_newrel_60_11_em_nvt2_fixed/R19.pdbqt',  '3'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_17_86_em_nvt2_fixed/R80.pdbqt',  '5'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_2_73_em_nvt10_fixed/R45.pdbqt',  '7'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_33_5_em_nvt39_fixed/R36.pdbqt',  '9'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_34_41_em_nvt40_fixed/R68.pdbqt',  '1'],
    ['/home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf9rel_40_10_em_nvt30_fixed/R73.pdbqt',  '3']
]

# %% [markdown]
# # R

# %%
for f in best:
    # !babel -ipdbqt {f[0]} -h -opdb {f[0][:-6]+"h.pdb"} 
    with open(f[0][:-6]+"h.pdb") as fl:
        lines = fl.readlines()
    print f[0]
    strings = []
    for line in lines:
        if "MODEL" in line:
            model = line.split()[-1]
            if model == f[1]:
                strings.append(line)
            atoms = []

        if line[0:6].split()[0] == 'ATOM' and model == f[1]: 
            # create a dict for every line stating with ATOM
            atoms.append({\
                'AtomSerial':line[6:11].replace(' ',''),\
                'AtomName':line[12:16].replace(' ',''),\
                'AltLoc':line[16].replace(' ',''),\
                'ResName':line[17:20].replace(' ',''),\
                'Chain':line[21].replace(' ',''),\
                'ResNum':int(line[22:26].replace(' ','')),\
                'ResIns':line[26].replace(' ',''),\
                'x':float(line[30:38].replace(' ','')),\
                'y':float(line[38:46].replace(' ','')),\
                'z':float(line[46:54].replace(' ','')),\
                'Occupancy':line[54:60].replace(' ',''),\
                'TempFactor':line[60:66].replace(' ',''),\
                'SegmentID':line[72:76].replace(' ',''),\
                'ElementSymb':line[76:78].replace(' ',''),\
                'Charge':line[78:81].replace(' ','')})


        if "ENDMDL" in line and model == f[1]:           
            # Iterate over atoms and replace their names
            hyds = list(R)
            for at in range(len(atoms)):
                if "H" in atoms[at]["AtomName"]: 
                    atoms[at]["AtomName"] = hyds.pop(0)  

            # reorder atoms in "atoms" so they match .itp         
            reorder = [order.index(atom["AtomName"]) for atom in atoms]
            atoms = [atoms[i] for i in reorder]
            print len(atoms)
            # prepare for output
            num = 0
            for atom in atoms:
                num +=1
                strings.append("%-6s%5d  %-4s%-3s %1s%4d    %8.3f%8.3f%8.3f%6.2s%6.2s          %2s%2s\n"%\
                                ("ATOM", num, atom['AtomName'], atom['ResName'],\
                                 atom['Chain'], atom["ResNum"], atom['x'], atom['y'], atom['z'],'', '', "",""))
            strings.append("ENDMDL\n")
            break
    with open(f[0][:-6] + "-ready.pdb",'w') as ff:
        ff.writelines(strings)
# Out:
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf0_3rel_32_82_em_nvt7_fixed/R42.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_55_em_nvt22_fixed/R65.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_35_78_em_nvt24_fixed/R4.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3_newrel_8_34_em_nvt13_fixed/R21.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_57_60_em_nvt_fixed/R13.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# /home/domain/data/kirill/AB/XOP/docking/lom_results/a5RY33Lprf12_3rel_61_55_em_nvt8_fixed/R29.pdbqt
# 52
# 9 molecules converted
# 234 audit log messages
# ...

# %%
atoms
# Out:
# []

# %%
reorder
# Out:
# [6,
#  9,
#  11,
#  13,
#  16,
#  19,
#  22,
#  25,
#  27,
#  7,
#  1,
#  0,
#  3,
#  31,
#  34,
#  39,
#  41,
#  37,
#  32,
#  2,
#  36,
#  45,
#  49,
#  51,
#  47,
#  43,
#  8,
#  4,
#  5]

# %% [markdown]
# # S

# %%
for dr in dirs:
    fname = dr + "/" + dr + "S"
    f = open(fname + ".pdb", 'r')
    lines = f.readlines()
    f.close()
    print f.name
    strings = []
    for line in lines:
        if "MODEL" in line:
            strings.append(line)
            atoms = []

        #read pdb

        if line[0:6].split()[0] == 'ATOM': 
            
            # create a dict for every line stating with ATOM
            atoms.append({\
                'AtomSerial':line[6:11].replace(' ',''),\
                'AtomName':line[12:16].replace(' ',''),\
                'AltLoc':line[16].replace(' ',''),\
                'ResName':line[17:20].replace(' ',''),\
                'Chain':line[21].replace(' ',''),\
                'ResNum':int(line[22:26].replace(' ','')),\
                'ResIns':line[26].replace(' ',''),\
                'x':float(line[30:38].replace(' ','')),\
                'y':float(line[38:46].replace(' ','')),\
                'z':float(line[46:54].replace(' ','')),\
                'Occupancy':line[54:60].replace(' ',''),\
                'TempFactor':line[60:66].replace(' ',''),\
                'SegmentID':line[72:76].replace(' ',''),\
                'ElementSymb':line[76:78].replace(' ',''),\
                'Charge':line[78:81].replace(' ','')})
        
            
        if "ENDMDL" in line:           
            # Iterate over atoms and replace their names
            hyds = list(R)
            for at in range(len(atoms)):
                if "H" in atoms[at]["AtomName"]: 
                    atoms[at]["AtomName"] = hyds.pop(0)  

            # reorder atoms in "atoms" so they match .itp         
            reorder = [order.index(atom["AtomName"]) for atom in atoms]
            atoms = [atoms[i] for i in reorder]
            
            # prepare for output
            num = 0
            for atom in atoms:
                num +=1
                strings.append("%-6s%5d  %-4s%-3s %1s%4d    %8.3f%8.3f%8.3f%6.2s%6.2s          %2s%2s\n"%\
                                ("ATOM", num, atom['AtomName'], atom['ResName'],\
                                 atom['Chain'], atom["ResNum"], atom['x'], atom['y'], atom['z'],'', '', "",""))
            strings.append("ENDMDL\n")
            
   
    pdb = open(fname + "-ready.pdb",'w')

    pdb.writelines(strings)
    pdb.close()
# Out:
# a1/a1S.pdb
# a21/a21S.pdb
# a43/a43S.pdb
# a46/a46S.pdb
# a49/a49S.pdb
# a5/a5S.pdb
# a7/a7S.pdb

# %% [markdown]
# # fix after rosetta

# %%
import os
os.chdir("/home/domain/data/kirill/AB/XOP/rosetta/several_ts/for_qm/")

# %%
import sys
ff = "a5RY33Lprf0_4_newrel_10_77-lig.pdb"
order = ['P', 'O', 'O1', 'O2', 'O3', 'O4', 'N', 'H', 'N1', 'C', 'H1', 'C1', 'H2', 'C2', 'H3', 'H4', 'C3', 
         'H5', 'H6', 'C4', 'H7', 'H8', 'C5', 'H9', 'H10', 'C6', 'H11', 'C7', 'H12', 'H13', 'H14', 'C8', 
         'C9', 'H15', 'C10', 'H16', 'C11', 'C12', 'H17', 'C13', 'H18', 'C14', 'H19', 'C15', 'H20', 'C16', 
         'H21', 'C17', 'H22', 'C18', 'H23', 'C19']

with open(ff) as f:
    lines = f.readlines()

dic = []    
for line in lines:
    k = line.split()[2]
    dic.append([k,line])
    
dic = sorted(dic, key = lambda x: order.index(x[0]))
with open(ff,"w") as f:
    f.writelines([d[1] for d in dic])

# %%
[d[0] for d in dic]
# Out:
# ['P',
#  'O',
#  'O1',
#  'O2',
#  'O3',
#  'O4',
#  'N',
#  'H',
#  'N1',
#  'C',
#  'H1',
#  'C1',
#  'H2',
#  'C2',
#  'H3',
#  'H4',
#  'C3',
#  'H5',
#  'H6',
#  'C4',
#  'H7',
#  'H8',
#  'C5',
#  'H9',
#  'H10',
#  'C6',
#  'H11',
#  'C7',
#  'H12',
#  'H13',
#  'H14',
#  'C8',
#  'C9',
#  'H15',
#  'C10',
#  'H16',
#  'C11',
#  'C12',
#  'H17',
#  'C13',
#  'H18',
#  'C14',
#  'H19',
#  'C15',
#  'H20',
#  'C16',
#  'H21',
#  'C17',
#  'H22',
#  'C18',
#  'H23',
#  'C19']
